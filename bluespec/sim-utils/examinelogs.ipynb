# %%
from parselog import *

# %%
lp = LogParser(
    log="results/late_counters_test_7-cap_chaser-l1ll/treeadd/sim_stdout.gz", 
    lineTypesToPrune=[None, NonRVFILine],
    # If a timestamped line matches, then either RVFILine or NonRVFILine will match
    lineTypesToError=[TimestampedLine],
    RootLogLine=TimestampedLine,
    startWhen=(lambda ll: isinstance(ll, RVFILine) and ll.rvfi >= 10000),
)
# Out:
# Loaded 957824 log lines
# 	RVFILine:                    470897 instances
# 	CRqHitLine:                  174637 instances
# 	CRqCreationLine:             175073 instances
# 	CRqHitDataLine:              94385 instances
# 	TLBIncorrectSpeculationLine: 10311 instances
# 	CRqMissLine:                 5019 instances
# 	CRqDependencyLine:           2333 instances
# 	LLCRqCreationLine:           7968 instances
# 	LLCRqMissLine:               2790 instances
# 	LLCRqHitLine:                7945 instances
# 	PRqLine:                     36 instances
# 	CapChaserTLBResponseLine:    6332 instances
# 	LLCRqDependencyLine:         98 instances
# Pre-processed 957824 log lines
# Post-processed 957824 log lines
# End-processed 957824 log lines
# Accumulated totals and dists for 957824 log lines

# %%
lp.printTotals()
# Out:
# RVFILine totals:
# 	total: 470897
# 	discard: 0
# 	warning: 0
#
# CRqHitLine totals:
# 	total: 174637
# 	discard: 0
# 	warning: 1
# 	warning(no creation of cRq): 1
# 	demandAccessedCap: 46076
#
# CRqCreationLine totals:
# 	total: 175072
# 	discard: 1
# 	warning: 0
# 	Pr: 2058
# 	St: 78629
# 	demand: 173014
# 	demandHit: 167247
# 	demandMiss: 3870
# 	demandMissLL: 2193
# 	demandOwned: 1897
# 	demandQueued: 0
# 	demandMissToLDS: 1156
# 	demandMissLoadToLDS: 1093
# 	demandMissLLToLDS: 104
# 	demandMissLLLoadToLDS: 101
# 	prefetch: 2058
# 	prefetchHit: 473
# 	prefetchMiss: 1149
# 	prefetchMissLL: 134
# 	prefetchOwned: 436
# 	latePrefetch: 991
# 	latePrefetchCreation: 0
# 	latePrefetchIssue: 991
# 	lateUsefulPrefetch: 991
# 	prefUnderPref: 4
# 	usefulPrefetch: 1129
# 	uselessPrefetch: 20
# 	uselessPrefetchBecausePerms: 0
# 	uselessPrefetchDisruption: 2
# 	prefetchDisruption: 69
# 	Ld: 94385
# 	discard(no cRq response): 1
#
# CRqHitDataLine totals:
# 	total: 94385
# 	discard: 0
# 	warning: 0
#
# TLBIncorrectSpeculationLine totals:
# 	total: 10311
# 	discard: 0
# 	warning: 0
#
# CRqMissLine totals:
# 	total: 5019
# 	discard: 0
# 	warning: 0
# 	E --/Ld/--> E: 1074
# 	M --/Ld/--> E: 536
# 	M --/St/--> M: 2000
# 	E --/St/--> M: 238
# 	I --(Ld)--> E: 7
# 	I --/Ld/--> E: 8
# 	I --/St/--> M: 5
# 	M --/Pr/--> S: 112
# 	E --/Pr/--> S: 1025
# 	I --/Pr/--> S: 12
# 	I --(St)--> M: 2
#
# CRqDependencyLine totals:
# 	total: 2333
# 	discard: 0
# 	warning: 0
# 	demand: 1897
# 	resolveHit: 1897
# 	resolveMiss: 0
#
# LLCRqCreationLine totals:
# 	total: 7968
# 	discard: 0
# 	warning: 0
# 	demand: 5137
# 	demandHit: 2622
# 	demandMiss: 2440
# 	demandOwned: 75
# 	prefetch: 2831
# 	prefetchHit: 2458
# 	prefetchMiss: 350
# 	prefetchOwned: 23
# 	prefetchOwnedAddr: 23
# 	prefetchOwnedDemandAddr: 2
# 	prefetchOwnedRep: 0
# 	usefulPrefetch: 349
# 	uselessPrefetch: 1
#
# LLCRqMissLine totals:
# 	total: 2790
# 	discard: 0
# 	warning: 0
#
# LLCRqHitLine totals:
# 	total: 7945
# 	discard: 0
# 	warning: 0
#
# PRqLine totals:
# 	total: 36
# 	discard: 0
# 	warning: 0
#
# CapChaserTLBResponseLine totals:
# 	total: 6332
# 	discard: 0
# 	warning: 0
#
# LLCRqDependencyLine totals:
# 	total: 98
# 	discard: 0
# 	warning: 0
